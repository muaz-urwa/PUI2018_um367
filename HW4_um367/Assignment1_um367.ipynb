# %% [markdown]
#  Written by Federica B. Bianco @fedhere
#  NYU CUSP PUI
#
#  Assignment 1 Homework 4
#
#  This is a skeleton & instruction notebook
#
# -  GENERATE  100 samples of different sizes N (N>10 & N<2000) from each of 5 different distributions (500 samples in total),
#  _all with the same population mean_. Include a _Normal_, a _Poisson_, a _Binomial_, a _Chi-Squared_ distribution, and 1 more of your choice.
# -  For each sample plot the sample mean (dependent var.) against the sample size N (independent var.) (if you want you can do it with the sample standard deviation as well).
# -  Describe the behavior you see in the plots in terms of the law of large numbers.
# -  PLOT the distributions of all sample means (together for all distributions). _Mandatory_: as a histogram. _Optional_: in any other way you think is convincing
#  Extra Credit: FIT a gaussian to the distribution of means

# %%
from __future__ import print_function
__author__= 'fbb'

import pylab as pl
# this package sets up pretty plots
import seaborn
from scipy.optimize import curve_fit, minimize
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## choose which distributions to use

# %%
#distributions = ['pois', 'gaus', 'chisq', 'cauchy', 'lnorm', 'binomial']
distributions = ['chisq']

# %% [markdown]
# ## and which mean to give it

# %%
mymean = 100

# %% [markdown]
# # Let's see what this distribution looks like, what is the PDF, and how are the moments defined. Wikipedia is great for this!
#
# ![1](chisq1.png)
#
# ![2](chisq2.png)

# %% [markdown]
# # Then lets look at the numpy random sampling package to see how I create the distribution
# http://docs.scipy.org/doc/numpy/reference/routines.random.html
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.chisquare.html#numpy.random.chisquare

# %%
# the chi sq distribution takes the number of degrees of freedom, which luckily is the same as the mean!
df = mymean

# %% [markdown]
# ## I am making a dictionary to host the distributions.
#
# that is only one possible option. with a dictionary I can easily inspect the distribution I want by its name: it is a very human friendly data storage. In this example I am only using a single distribution, so for me it is overkill, but if I were doing the whole exercise with 5 or 6 distributions it would be useful!
#
# Lets start by looking at a single chi sq distribution

# %%
# Note: I am adding imports here, to show the workflow: 
# at this point I realize what packages I need and I import them. 
# but this is a PEP8 violation. 
# It is a good habit to put the includes at the top 
# so the code fails right away if the packages are missing. 
# Otherwise a user may have a piece of code running for a long time, 
# and then fail when the package cannot be imported... 
# (unless they are only imported under conditions, e.g. in an if statement)

import numpy as np
md = {}
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
_=pl.xlabel('x')

# %% [markdown]
# ### Figure 1: Chi sq distribution: df = 100, N=100

# %% [markdown]
# ## let numpy calculate what the mean and stdev of this distribution are

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 101.05, standard deviation: 12.82

# %% [markdown]
# ## Now let's do it for 100 Chisq distributions
# we want distributions of different sizes (all integers between 10 and 2000)

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142
#   133  125  117  111  105  100   95   90   86   83   80   76   74   71
#    68   66   64   62   60   58   57   55   54   52   51   50   48   47
#    46   45   44   43   42   41   40   40   39   38   37   37   36   35
#    35   34   33   33   32   32   31   31   30   30   29   29   28   28
#    28   27   27   27   26   26   25   25   25   25   24   24   24   23
#    23   23   22   22   22   22   21   21   21   21   21   20   20   20
#    20] (99,)

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)

md['chisq'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
# save the means for plotting later    

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 2: As the sample size increases the sample mean becomes closer to the population mean as stated by the law of large numbers. We see that the larger samples(which are further to the right) are closer to hte black line whihc depicts mean.  Varriance of the means decreases with the increase in sample size.

# %% [markdown]
# # now the histogram of the mean of all samples:
# ## this requires some data wrangling, since i put the data in a dictionary which is a user friendly data structure, but perhaps not the most machine friendly one
#
# a coder friendly, though not terribly pythonic way to do it is to append each mean in a list in a for loop, and then hist that. be careful: if your data size gets large this becomes a very bad idea!!

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.title('Means of Sample from Chi Squared df=100')
_=pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from Chi squared. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %% [markdown]
# # Do it for the Normal distribution

# %%
norm_standardDeviation = 10

md['gaus'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['gaus'][n] =  np.random.normal(loc=mymean, scale=norm_standardDeviation, size=n)
    
# save the means for plotting later    

md['gaus']['means'] = {}
axgaus_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['gaus']:
    if not type(nn) == str:
        md['gaus']['means'][nn] = md['gaus'][nn].mean()
        #and plot it
        axgaus_mu_n.plot(nn, md['gaus']['means'][nn], 'o')
        axgaus_mu_n.set_xlabel('sample size', fontsize=18)
        axgaus_mu_n.set_ylabel('sample mean', fontsize=18)
        axgaus_mu_n.set_title('Gaussain', fontsize=18)
        axgaus_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from Chi squared. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %%
allmeans = list(md['gaus']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.title("Samples from Gaussian DIstribution mean=100 sd=10")
_=pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from Chi squared. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %% [markdown]
# # Do it for the Poisson distribution

# %%
poisson_lambda = mymean

md['pois'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['pois'][n] =  np.random.poisson(lam=poisson_lambda, size=n)
    
# save the means for plotting later    

md['pois']['means'] = {}
axpois_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axpois_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('Poisson', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')

# %% [markdown]
# #### Figure 3: Means of samples drawn from Poisson are plotted against the sample size. As stated by law of large numbers, bigger samples have means closer to the population mean.

# %%
allmeans = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.title("Samples from Poisson DIstribution lambda=100")
_=pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from Poisson distribution. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %% [markdown]
# # Do it for the Binomial distribution

# %%
#Set Probability of success in each trial
p = 0.5
#Set number of trials
tials = mymean/p

md['binomial'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['binomial'][n] =  np.random.binomial(tials ,p , size=n)
    
# save the means for plotting later    

md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('Bionomial p=0.5', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')

# %% [markdown]
# #### Figure 3: Means of samples drawn from Bionomial distribution are plotted against the sample size. As stated by law of large numbers, bigger samples have means closer to the population mean.

# %%
allmeans = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.title("Samples from Bionomial DIstribution p=0.5")
_=pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from Bionomial distribution. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %% [markdown]
# lnorm

# %% [markdown]
# # Do it for another distribution

# %%
sigma = 1
#miu is mean of underlying normal distribution
miu = np.log(mymean)-(sigma**2)/2
print('miu: '+str(miu))

md['lnorm'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['lnorm'][n] =  np.random.lognormal(miu ,sigma, size=n)
    
# save the means for plotting later    

md['lnorm']['means'] = {}
axlnorm_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['lnorm']:
    if not type(nn) == str:
        md['lnorm']['means'][nn] = md['lnorm'][nn].mean()
        #and plot it
        axlnorm_mu_n.plot(nn, md['lnorm']['means'][nn], 'o')
        axlnorm_mu_n.set_xlabel('sample size', fontsize=18)
        axlnorm_mu_n.set_ylabel('sample mean', fontsize=18)
        axlnorm_mu_n.set_title('Lognormal', fontsize=18)
        axlnorm_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')
# Out:
# miu: 4.105170185988092

# %% [markdown]
# #### Figure 3: Means of samples drawn from Lognormal distribution are plotted against the sample size. As stated by law of large numbers, bigger samples have means closer to the population mean.

# %%
allmeans = list(md['lnorm']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.title("Samples from Bionomial DIstribution miu=4.105 sigma=1")
_=pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from Lognormal distribution. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %%
meansOfAllDistributions = []
for dist in md:
    meansOfAllDistributions = meansOfAllDistributions+list(md[dist]['means'].values())

# %%
pl.figure(figsize=(10, 10))
pl.hist(meansOfAllDistributions,bins=30)
pl.xlabel('sample mean all distributions', fontsize = 18)
pl.title("Samples from All DIstribution")
_=pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Histogram of means of samples drawn from All distributions. This is the manifestation of the central limit theorem, because the sample means are normally distributed.  If you increase the number of samples the distribution will follow the bell shape more closely.

# %% [markdown]
# #### Fitting a normal  distribution to the data

# %%
from scipy.stats import norm
mu, std = norm.fit(meansOfAllDistributions)

# %%
# Plot the histogram.
plt.hist(meansOfAllDistributions, bins=30, density=True, alpha=0.6, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
_=plt.title(title)

# %% [markdown]
# #### Figure 3: Normal distribution fitted to the means of all distributions
